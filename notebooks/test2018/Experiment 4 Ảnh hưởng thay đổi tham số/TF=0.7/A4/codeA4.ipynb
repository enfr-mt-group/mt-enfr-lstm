# %%
import os
if not os.path.exists('/kaggle/working/remoteSSH'):
    # !git clone https://github.com/Quanquan1906/remoteSSH.git
# Out:
# Cloning into 'remoteSSH'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 1), reused 14 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/remoteSSH
# Out:
# /kaggle/working/remoteSSH

# %%
from remote_setup import setup_github_config, connect_vscode, clone_project_from_github
setup_github_config('/kaggle/input/myprojecttree/Admin_rsa')
clone_project_from_github(giturl='git@github.com:enfr-mt-group/mt-enfr-lstm.git',
                          folder='/kaggle/working/enfr-mt-group',
                          branch='base-attention-beemsearch')
# connect_vscode()
# Out:
# setup github_config finished
# Cloning into '/kaggle/working/enfr-mt-group'...
#
# remote: Enumerating objects: 818, done.
# remote: Counting objects: 100% (295/295), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 818 (delta 144), reused 216 (delta 73), pack-reused 523 (from 2)
# Receiving objects: 100% (818/818), 421.13 MiB | 45.21 MiB/s, done.
# Resolving deltas: 100% (378/378), done.

# %%
cd /kaggle/working/enfr-mt-group
# Out:
# /kaggle/working/enfr-mt-group

# %% [markdown]
# # **Mô hình LSTM ENGLISH TO FRANCE**

# %%
# !python /kaggle/working/enfr-mt-group/enfr-main/src/main/main.py --exp A4
# Out:
# Using preset: A4
# {'embed_dim': 512, 'hidden_dim': 512, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 128, 'lr': 0.001, 'teacher_forcing_ratio': 0.7, 'n_epochs': 20, 'use_attention': True}
# Building DataLoaders...
# Tokenizing EN: 100%|███████████████████| 29000/29000 [00:00<00:00, 29290.69it/s]
# Tokenizing FR: 100%|███████████████████| 29000/29000 [00:01<00:00, 17905.48it/s]
# Tokenizing EN: 100%|█████████████████████| 1014/1014 [00:00<00:00, 37870.64it/s]
# Tokenizing FR: 100%|█████████████████████| 1014/1014 [00:00<00:00, 24533.05it/s]
# Tokenizing EN: 100%|█████████████████████| 1071/1071 [00:00<00:00, 33489.89it/s]
# Tokenizing FR: 100%|█████████████████████| 1071/1071 [00:00<00:00, 22798.83it/s]
# Dataset sizes: Train=29000, Val=1014, Test=1071
# Vocab sizes: EN=9797, FR=10004
# Model initialized
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/20] | Train Loss: 4.5518 | Val Loss: 3.5869
#  Best model saved
# Epoch [2/20] | Train Loss: 3.2912 | Val Loss: 2.8517
#  Best model saved
# Epoch [3/20] | Train Loss: 2.6964 | Val Loss: 2.4333
#  Best model saved
# Epoch [4/20] | Train Loss: 2.3154 | Val Loss: 2.1856
#  Best model saved
# Epoch [5/20] | Train Loss: 2.0490 | Val Loss: 2.0231
#  Best model saved
# Epoch [6/20] | Train Loss: 1.8448 | Val Loss: 1.8977
#  Best model saved
# Epoch [7/20] | Train Loss: 1.6910 | Val Loss: 1.8663
#  Best model saved
# Epoch [8/20] | Train Loss: 1.5453 | Val Loss: 1.7804
#  Best model saved
# Epoch [9/20] | Train Loss: 1.4431 | Val Loss: 1.7560
#  Best model saved
# Epoch [10/20] | Train Loss: 1.3411 | Val Loss: 1.7286
#  Best model saved
# Epoch [11/20] | Train Loss: 1.2556 | Val Loss: 1.7277
#  Best model saved
# Epoch [12/20] | Train Loss: 1.1887 | Val Loss: 1.6658
#  Best model saved
# Epoch [13/20] | Train Loss: 1.1174 | Val Loss: 1.6523
#  Best model saved
# Epoch [14/20] | Train Loss: 1.0799 | Val Loss: 1.6605
# Epoch [15/20] | Train Loss: 1.0303 | Val Loss: 1.6592
# Epoch [16/20] | Train Loss: 0.9821 | Val Loss: 1.6360
#  Best model saved
# Epoch [17/20] | Train Loss: 0.9474 | Val Loss: 1.6480
# Epoch [18/20] | Train Loss: 0.9155 | Val Loss: 1.6430
# Epoch [19/20] | Train Loss: 0.8742 | Val Loss: 1.6598
# Early stopping at epoch 19
# Training hoàn thành. Best Val Loss: 1.6360
# Figure(1000x600)
# Best model loaded
#
#  Translation examples:
# EN: a man wearing a hat is standing in front of a book store while looking at a window .
# FR(pred): un homme portant un chapeau est debout devant un magasin de magasin tandis qu' il regarde une vitrine .
#
# EN: a girl in a pink coat is looking for a book while standing in a building .
# FR(pred): une fille en manteau rose regarde un livre tandis qu' elle est debout dans un bâtiment .
#
# EN: a person wearing goggles is sledding down a hill in front of a building .
# FR(pred): une personne portant des lunettes de natation descend une pente devant un bâtiment .
#
# Evaluating on test set...
#
# ==============================
# Average BLEU score: 0.2663
# Perplexity: 14.0059
# ==============================
#
# ----- EXAMPLES -----
# EN: a man with a beard is seen through a window holding a cup , while a man in the background reads a newspaper .
# FR(pred): un homme avec une barbe est à travers une fenêtre en tenant un gobelet , tandis qu' un homme en arrière-plan lit un journal .
# FR(true): on peut voir un homme barbu à travers une fenêtre tenir un gobelet , pendant qu' un homme en arrière-plan lit un journal .
# BLEU: 0.4910
#
# EN: a black and white image of a woman in a coffee shop , and a reflection of a car in the window .
# FR(pred): une photo noire et blanche d' une femme dans un salon de café , et un sourire dans la vitrine .
# FR(true): une image en noir et blanc d' une femme à un café , et le reflet d' une voiture dans la fenêtre .
# BLEU: 0.0869
#
# EN: this image is of a little girl leaning against her parents bed while she 's looking at herself in the mirror .
# FR(pred): cette photo est celle d' une petite fille penchée contre son téléphone portable tandis qu' elle regarde au miroir .
# FR(true): c' est l' image d' une petite fille appuyée contre le lit de ses parents pendant qu' elle observe son reflet dans le miroir .
# BLEU: 0.1366
#
# EN: this is a young girl looking at a phone while the boy beside her is looking straight in to the camera .
# FR(pred): cette est un jeune fille regardant un téléphone tandis que le garçon à côté de son garçon regarde l' objectif .
# FR(true): on voit une jeune fille en train de regarder son téléphone avec un garçon à côté d' elle qui regarde directement vers la caméra .
# BLEU: 0.0572
#
# EN: a person dressed in white motocross gear sits on a white atv with a scenic view of mountains behind them .
# FR(pred): une personne habillée en tenue de sport blanche est assise sur un quad blanc avec un paysage paysage derrière elle .
# FR(true): une personne vêtue d' un costume de motocross blanc sur un 4x4 de la même couleur avec une vue panoramique des montagnes derrière lui .
# BLEU: 0.0284
#
#
# Final BLEU: 0.2663
# Final Perplexity: 14.0059
# Số lượng trọng số: 22
#
# BẢNG 1: DANH SÁCH TOÀN BỘ THAM SỐ
# +-------------------------------+----------------+----------------+
# | Layer Name                    | Tensor Shape   |   Số Parameter |
# +===============================+================+================+
# | encoder.embedding.weight      | [9797, 512]    |        5016064 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.embedding.weight      | [10004, 512]   |        5122048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.weight | [512, 512]     |         262144 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.bias   | [512]          |            512 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.weight         | [10004, 1024]  |       10244096 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.bias           | [10004]        |          10004 |
# +-------------------------------+----------------+----------------+
#
# BẢNG 2: EMBEDDING
# +--------------------------+--------------+----------+
# | Layer                    | Shape        |   Params |
# +==========================+==============+==========+
# | encoder.embedding.weight | [9797, 512]  |  5016064 |
# +--------------------------+--------------+----------+
# | decoder.embedding.weight | [10004, 512] |  5122048 |
# +--------------------------+--------------+----------+
#
# BẢNG 3: LSTM ENCODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | encoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 4: LSTM DECODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | decoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 5: ATTENTION
# +-------------------------------+------------+----------+
# | Layer                         | Shape      |   Params |
# +===============================+============+==========+
# | decoder.attention.attn.weight | [512, 512] |   262144 |
# +-------------------------------+------------+----------+
# | decoder.attention.attn.bias   | [512]      |      512 |
# +-------------------------------+------------+----------+
#
# BẢNG 6: FULLY CONNECTED OUTPUT
# +-----------------------+---------------+----------+
# | Layer                 | Shape         |   Params |
# +=======================+===============+==========+
# | decoder.fc_out.weight | [10004, 1024] | 10244096 |
# +-----------------------+---------------+----------+
# | decoder.fc_out.bias   | [10004]       |    10004 |
# +-----------------------+---------------+----------+
#
# TỔNG SỐ PARAMETER CỦA MÔ HÌNH: 29,059,860
#
#  Kết quả được lưu vào experiment_results.csv
