# %%
import os
if not os.path.exists('/kaggle/working/remoteSSH'):
    # !git clone https://github.com/Quanquan1906/remoteSSH.git
# Out:
# Cloning into 'remoteSSH'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# Receiving objects: 100% (15/15), done.
# remote: Total 15 (delta 1), reused 14 (delta 0), pack-reused 0 (from 0)
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/remoteSSH
# Out:
# /kaggle/working/remoteSSH

# %%
from remote_setup import setup_github_config, connect_vscode, clone_project_from_github
setup_github_config('/kaggle/input/myprojecttree/Admin_rsa')
clone_project_from_github(giturl='git@github.com:enfr-mt-group/mt-enfr-lstm.git',
                          folder='/kaggle/working/enfr-mt-group',
                          branch='base-attention-beemsearch')
connect_vscode()
# Out:
# setup github_config finished
# Cloning into '/kaggle/working/enfr-mt-group'...
#
# remote: Enumerating objects: 818, done.
# remote: Counting objects: 100% (295/295), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 818 (delta 144), reused 216 (delta 73), pack-reused 523 (from 2)
# Receiving objects: 100% (818/818), 421.13 MiB | 46.59 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# ********** SETUP SSH SERVICE **********
# New password: Retype new password: passwd: password updated successfully
#  * Restarting OpenBSD Secure Shell server sshd
#    ...done.
# ---------- Finished ----------
# /bin/bash: line 1: kill: `': not a pid or valid job spec
# ********** SETUP NGROK **********
# t=2025-12-10T00:43:37+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.\nRun multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.\nRead more about the agent configuration file: https://ngrok.com/docs/agent/config/ \nYou can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:\nhttps://dashboard.ngrok.com/billing/choose-a-plan\r\n\r\nERR_NGROK_108\r\n"
# ERROR:  authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.
# ERROR:  Run multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.
# ERROR:  Read more about the agent configuration file: https://ngrok.com/docs/agent/config/
# ERROR:  You can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:
# ERROR:  https://dashboard.ngrok.com/billing/choose-a-plan
# ERROR:
# ERROR:  ERR_NGROK_108
# ERROR:  https://ngrok.com/docs/errors/err_ngrok_108
# ERROR:
# t=2025-12-10T00:43:37+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.\nRun multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.\nRead more about the agent configuration file: https://ngrok.com/docs/agent/config/ \nYou can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:\nhttps://dashboard.ngrok.com/billing/choose-a-plan\r\n\r\nERR_NGROK_108\r\n"
# t=2025-12-10T00:43:37+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# The ngrok process errored on start: authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.\nRun multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.\nRead more about the agent configuration file: https://ngrok.com/docs/agent/config/ \nYou can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:\nhttps://dashboard.ngrok.com/billing/choose-a-plan\r\n\r\nERR_NGROK_108\r\n.
# t=2025-12-10T00:43:37+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T00:43:38+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T00:43:40+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T00:43:44+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T00:43:52+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# The ngrok process errored on start: failed to dial ngrok server with address "connect.en.ngrok-agent.com:443": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host.
# > Registry success!
# ssh: NgrokTunnel: "tcp://0.tcp.au.ngrok.io:16070" -> "localhost:22"
# vscode: NgrokTunnel: "https://bd4015ecadd1.ngrok-free.app" -> "http://localhost:9000"

# %%
cd /kaggle/working/enfr-mt-group
# Out:
# /kaggle/working/enfr-mt-group

# %% [markdown]
# # **Mô hình LSTM ENGLISH TO FRANCE**

# %%
# !python /kaggle/working/enfr-mt-group/enfr-main/src/main/main.py --exp A2
# Out:
# Using preset: A2
# {'embed_dim': 512, 'hidden_dim': 512, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'lr': 0.001, 'teacher_forcing_ratio': 0.7, 'n_epochs': 20, 'use_attention': True}
# Building DataLoaders...
# Tokenizing EN: 100%|███████████████████| 29000/29000 [00:00<00:00, 31371.84it/s]
# Tokenizing FR: 100%|███████████████████| 29000/29000 [00:01<00:00, 19225.40it/s]
# Tokenizing EN: 100%|█████████████████████| 1014/1014 [00:00<00:00, 39351.07it/s]
# Tokenizing FR: 100%|█████████████████████| 1014/1014 [00:00<00:00, 25096.18it/s]
# Tokenizing EN: 100%|█████████████████████| 1071/1071 [00:00<00:00, 35239.89it/s]
# Tokenizing FR: 100%|█████████████████████| 1071/1071 [00:00<00:00, 23657.20it/s]
# Dataset sizes: Train=29000, Val=1014, Test=1071
# Vocab sizes: EN=9797, FR=10004
# Model initialized
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/20] | Train Loss: 3.9304 | Val Loss: 2.9478
#  Best model saved
# Epoch [2/20] | Train Loss: 2.7001 | Val Loss: 2.3419
#  Best model saved
# Epoch [3/20] | Train Loss: 2.1917 | Val Loss: 2.0414
#  Best model saved
# Epoch [4/20] | Train Loss: 1.8849 | Val Loss: 1.9151
#  Best model saved
# Epoch [5/20] | Train Loss: 1.6664 | Val Loss: 1.7963
#  Best model saved
# Epoch [6/20] | Train Loss: 1.4909 | Val Loss: 1.7881
#  Best model saved
# Epoch [7/20] | Train Loss: 1.3712 | Val Loss: 1.7485
#  Best model saved
# Epoch [8/20] | Train Loss: 1.2615 | Val Loss: 1.7210
#  Best model saved
# Epoch [9/20] | Train Loss: 1.1743 | Val Loss: 1.7410
# Epoch [10/20] | Train Loss: 1.1086 | Val Loss: 1.6982
#  Best model saved
# Epoch [11/20] | Train Loss: 1.0470 | Val Loss: 1.7078
# Epoch [12/20] | Train Loss: 1.0004 | Val Loss: 1.6979
#  Best model saved
# Epoch [13/20] | Train Loss: 0.9565 | Val Loss: 1.7187
# Epoch [14/20] | Train Loss: 0.9144 | Val Loss: 1.7208
# Epoch [15/20] | Train Loss: 0.8799 | Val Loss: 1.7031
# Early stopping at epoch 15
# Training hoàn thành. Best Val Loss: 1.6979
# Figure(1000x600)
# Best model loaded
#
#  Translation examples:
# EN: a man wearing a hat is standing in front of a book store while looking at a window .
# FR(pred): un homme portant un chapeau est debout devant un livre , regardant une vitrine .
#
# EN: a girl in a pink coat is looking for a book while standing in a building .
# FR(pred): une fille en manteau rose regarde un livre tandis qu' elle est debout dans un bâtiment .
#
# EN: a person wearing goggles is sledding down a hill in front of a building .
# FR(pred): une personne portant des lunettes fait une pente devant un bâtiment .
#
# Evaluating on test set...
#
# ==============================
# Average BLEU score: 0.2574
# Perplexity: 16.1557
# ==============================
#
# ----- EXAMPLES -----
# EN: this is a young girl looking at a phone while the boy beside her is looking straight in to the camera .
# FR(pred): c' est une jeune fille regardant un téléphone portable tandis que le garçon à côté regarde l' objectif .
# FR(true): on voit une jeune fille en train de regarder son téléphone avec un garçon à côté d' elle qui regarde directement vers la caméra .
# BLEU: 0.0702
#
# EN: the man is scratching the back of his neck while looking for a book in a book store .
# FR(pred): l' homme coupe l' arrière de son véhicule tandis en regardant un livre dans un magasin .
# FR(true): l' homme se gratte l' arrière du cou tout en cherchant un livre dans une librairie .
# BLEU: 0.0891
#
# EN: this image is of a man and a woman walking on a beach in front of palm trees .
# FR(pred): cette photo d' un homme et une femme marchant sur une plage devant des palmiers .
# FR(true): c' est l' image d' un homme et d' une femme qui marchent sur une plage devant des palmiers .
# BLEU: 0.4424
#
# EN: dog laying on outdoor wooden bench , with dog statue beside , yellow tennis ball laying on ground .
# FR(pred): un chien couché sur un banc en bois , avec un chien plus gros statue , avec une statue de tennis jaune .
# FR(true): un chien est allongé sur un banc extérieur en bois , avec une statue de chien à côté de lui et il y a une balle de tennis jaune par terre .
# BLEU: 0.2456
#
# EN: four children are sitting against a wall having a conversation while two adult men stare into space .
# FR(pred): quatre enfants sont assis contre un mur où deux hommes hommes regardent une conversation tandis que deux autres hommes regardent .
# FR(true): quatre enfants sont assis contre un mur en pleine conversation pendant que les deux hommes adultes regardent ailleurs .
# BLEU: 0.3355
#
#
# Final BLEU: 0.2574
# Final Perplexity: 16.1557
# Số lượng trọng số: 22
#
# BẢNG 1: DANH SÁCH TOÀN BỘ THAM SỐ
# +-------------------------------+----------------+----------------+
# | Layer Name                    | Tensor Shape   |   Số Parameter |
# +===============================+================+================+
# | encoder.embedding.weight      | [9797, 512]    |        5016064 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.embedding.weight      | [10004, 512]   |        5122048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.weight | [512, 512]     |         262144 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.bias   | [512]          |            512 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.weight         | [10004, 1024]  |       10244096 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.bias           | [10004]        |          10004 |
# +-------------------------------+----------------+----------------+
#
# BẢNG 2: EMBEDDING
# +--------------------------+--------------+----------+
# | Layer                    | Shape        |   Params |
# +==========================+==============+==========+
# | encoder.embedding.weight | [9797, 512]  |  5016064 |
# +--------------------------+--------------+----------+
# | decoder.embedding.weight | [10004, 512] |  5122048 |
# +--------------------------+--------------+----------+
#
# BẢNG 3: LSTM ENCODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | encoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 4: LSTM DECODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | decoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 5: ATTENTION
# +-------------------------------+------------+----------+
# | Layer                         | Shape      |   Params |
# +===============================+============+==========+
# | decoder.attention.attn.weight | [512, 512] |   262144 |
# +-------------------------------+------------+----------+
# | decoder.attention.attn.bias   | [512]      |      512 |
# +-------------------------------+------------+----------+
#
# BẢNG 6: FULLY CONNECTED OUTPUT
# +-----------------------+---------------+----------+
# | Layer                 | Shape         |   Params |
# +=======================+===============+==========+
# | decoder.fc_out.weight | [10004, 1024] | 10244096 |
# +-----------------------+---------------+----------+
# | decoder.fc_out.bias   | [10004]       |    10004 |
# +-----------------------+---------------+----------+
#
# TỔNG SỐ PARAMETER CỦA MÔ HÌNH: 29,059,860
#
#  Kết quả được lưu vào experiment_results.csv
