# %%
import os
if not os.path.exists('/kaggle/working/remoteSSH'):
    # !git clone https://github.com/Quanquan1906/remoteSSH.git
# Out:
# Cloning into 'remoteSSH'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 1), reused 14 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/remoteSSH
# Out:
# /kaggle/working/remoteSSH

# %%
from remote_setup import setup_github_config, connect_vscode, clone_project_from_github
setup_github_config('/kaggle/input/myprojecttree/Admin_rsa')
clone_project_from_github(giturl='git@github.com:enfr-mt-group/mt-enfr-lstm.git',
                          folder='/kaggle/working/enfr-mt-group',
                          branch='base-attention-beemsearch')
# connect_vscode()
# Out:
# setup github_config finished
# Cloning into '/kaggle/working/enfr-mt-group'...
#
# remote: Enumerating objects: 901, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 901 (delta 121), reused 131 (delta 97), pack-reused 736 (from 1)
# Receiving objects: 100% (901/901), 421.87 MiB | 46.61 MiB/s, done.
# Resolving deltas: 100% (429/429), done.

# %%
cd /kaggle/working/enfr-mt-group
# Out:
# /kaggle/working/enfr-mt-group

# %% [markdown]
# # **Mô hình LSTM ENGLISH TO FRANCE**

# %%
# !python /kaggle/working/enfr-mt-group/enfr-main/src/main/main.py --exp A4
# Out:
# Using preset: A4
# {'embed_dim': 512, 'hidden_dim': 512, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 128, 'lr': 0.001, 'teacher_forcing_ratio': 0.5, 'n_epochs': 20, 'use_attention': False}
# Building DataLoaders...
# Tokenizing EN: 100%|███████████████████| 29000/29000 [00:00<00:00, 29675.23it/s]
# Tokenizing FR: 100%|███████████████████| 29000/29000 [00:01<00:00, 17890.72it/s]
# Tokenizing EN: 100%|█████████████████████| 1014/1014 [00:00<00:00, 36987.97it/s]
# Tokenizing FR: 100%|█████████████████████| 1014/1014 [00:00<00:00, 24152.70it/s]
# Tokenizing EN: 100%|█████████████████████| 1000/1000 [00:00<00:00, 38864.58it/s]
# Tokenizing FR: 100%|█████████████████████| 1000/1000 [00:00<00:00, 27773.35it/s]
# Dataset sizes: Train=29000, Val=1014, Test=1000
# Vocab sizes: EN=9797, FR=10004
# Model initialized
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/20] | Train Loss: 5.1041 | Val Loss: 4.3578
#  Best model saved
# Epoch [2/20] | Train Loss: 4.0768 | Val Loss: 3.6703
#  Best model saved
# Epoch [3/20] | Train Loss: 3.5526 | Val Loss: 3.2940
#  Best model saved
# Epoch [4/20] | Train Loss: 3.2138 | Val Loss: 3.0434
#  Best model saved
# Epoch [5/20] | Train Loss: 2.9526 | Val Loss: 2.8798
#  Best model saved
# Epoch [6/20] | Train Loss: 2.7331 | Val Loss: 2.7261
#  Best model saved
# Epoch [7/20] | Train Loss: 2.5520 | Val Loss: 2.6444
#  Best model saved
# Epoch [8/20] | Train Loss: 2.3960 | Val Loss: 2.5513
#  Best model saved
# Epoch [9/20] | Train Loss: 2.2558 | Val Loss: 2.4937
#  Best model saved
# Epoch [10/20] | Train Loss: 2.1316 | Val Loss: 2.4473
#  Best model saved
# Epoch [11/20] | Train Loss: 2.0151 | Val Loss: 2.3818
#  Best model saved
# Epoch [12/20] | Train Loss: 1.9153 | Val Loss: 2.3740
#  Best model saved
# Epoch [13/20] | Train Loss: 1.8203 | Val Loss: 2.3498
#  Best model saved
# Epoch [14/20] | Train Loss: 1.7321 | Val Loss: 2.3176
#  Best model saved
# Epoch [15/20] | Train Loss: 1.6555 | Val Loss: 2.3046
#  Best model saved
# Epoch [16/20] | Train Loss: 1.5833 | Val Loss: 2.3082
# Epoch [17/20] | Train Loss: 1.5120 | Val Loss: 2.2675
#  Best model saved
# Epoch [18/20] | Train Loss: 1.4438 | Val Loss: 2.2757
# Epoch [19/20] | Train Loss: 1.3852 | Val Loss: 2.2801
# Epoch [20/20] | Train Loss: 1.3266 | Val Loss: 2.3005
# Early stopping at epoch 20
# Training hoàn thành. Best Val Loss: 2.2675
# Figure(1000x600)
# Best model loaded
#
#  Translation examples:
# EN: a man wearing a hat is standing in front of a book store while looking at a window .
# FR(pred): un homme portant un chapeau est debout devant un magasin , regardant quelque chose à une fenêtre .
#
# EN: a girl in a pink coat is looking for a book while standing in a building .
# FR(pred): une fille en manteau rose regarde un livre tout en étant debout dans un bâtiment .
#
# EN: a person wearing goggles is sledding down a hill in front of a building .
# FR(pred): une personne portant des lunettes de soleil descend une pente devant un bâtiment .
#
# Evaluating on test set...
#
# ==============================
# Average BLEU score: 0.3368
# Perplexity: 8.7194
# ==============================
#
# ----- EXAMPLES -----
# EN: a boy in a red uniform is attempting to avoid getting out at home plate , while the catcher in the blue uniform is attempting to catch him .
# FR(pred): un garçon en maillot rouge tente de éviter de tente de avoir un plaquage de l' , tandis que le adversaire essaie de contrer .
# FR(true): un garçon en uniforme rouge essaie d' éviter de sortir du marbre , tandis que le receveur en tenue bleue essaie de l' attraper .
# BLEU: 0.1824
#
# EN: a woman in blue looks in a black leather bag while sitting on a bench during a sunny afternoon while people and <unk> passed behind her .
# FR(pred): une femme en costume noir et un costume noir tandis qu' elle est sur un banc tout en regardant des personnes et des personnes et des et et les autres .
# FR(true): une femme en bleu regarde dans un sac en cuir noir tandis qu' elle est assise sur un banc lors d' un après-midi ensoleillé , alors que des gens et une limousine passent derrière elle .
# BLEU: 0.1727
#
# EN: a father - figure and two children outside their home doing yard work such as using a hoe on the grass and planting a tree .
# FR(pred): une maman et deux enfants dehors leur leur à l' leur leur arbre et leur leur <unk> et un un un arbre par un arbre .
# FR(true): une figure <unk> et deux enfants devant leur maison , faisant des activités de jardinage comme utiliser une binette dans l' herbe et planter un arbre .
# BLEU: 0.0716
#
# EN: a man in light colored clothing photographs a group of men wearing dark suits and hats standing around a woman dressed in a <unk> gown .
# FR(pred): un homme en vêtements traditionnels couleur vive danse d' un groupe de femmes , portant des vêtements traditionnels , une femme portant des vêtements d' une veste de cuir .
# FR(true): un homme en tenue claire photographie un groupe d' hommes portant des costumes sombres et des chapeaux , debout autour d' une femme vêtue d' une robe <unk> .
# BLEU: 0.0608
#
# EN: a man in a black t - shirt , cap and jeans is playing drums on an upside down yellow pail .
# FR(pred): un homme avec un t - shirt noir et un jean , un jean joue de la guitare sur un tapis bleu .
# FR(true): un homme en t - shirt noir , casquette et jean joue de la percussion sur un seau jaune retourné .
# BLEU: 0.2592
#
#
# Final BLEU: 0.3368
# Final Perplexity: 8.7194
# Số lượng trọng số: 20
#
# BẢNG 1: DANH SÁCH TOÀN BỘ THAM SỐ
# +---------------------------+----------------+----------------+
# | Layer Name                | Tensor Shape   |   Số Parameter |
# +===========================+================+================+
# | encoder.embedding.weight  | [9797, 512]    |        5016064 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.embedding.weight  | [10004, 512]   |        5122048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.fc_out.weight     | [10004, 512]   |        5122048 |
# +---------------------------+----------------+----------------+
# | decoder.fc_out.bias       | [10004]        |          10004 |
# +---------------------------+----------------+----------------+
#
# BẢNG 2: EMBEDDING
# +--------------------------+--------------+----------+
# | Layer                    | Shape        |   Params |
# +==========================+==============+==========+
# | encoder.embedding.weight | [9797, 512]  |  5016064 |
# +--------------------------+--------------+----------+
# | decoder.embedding.weight | [10004, 512] |  5122048 |
# +--------------------------+--------------+----------+
#
# BẢNG 3: LSTM ENCODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | encoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 4: LSTM DECODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | decoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 5: ATTENTION
# +---------+---------+----------+
# | Layer   | Shape   | Params   |
# +=========+=========+==========+
# +---------+---------+----------+
#
# BẢNG 6: FULLY CONNECTED OUTPUT
# +-----------------------+--------------+----------+
# | Layer                 | Shape        |   Params |
# +=======================+==============+==========+
# | decoder.fc_out.weight | [10004, 512] |  5122048 |
# +-----------------------+--------------+----------+
# | decoder.fc_out.bias   | [10004]      |    10004 |
# +-----------------------+--------------+----------+
#
# TỔNG SỐ PARAMETER CỦA MÔ HÌNH: 23,675,156
#
#  Kết quả được lưu vào experiment_results.csv
