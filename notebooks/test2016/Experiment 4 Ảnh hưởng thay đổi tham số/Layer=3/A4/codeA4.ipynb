# %%
import os
if not os.path.exists('/kaggle/working/remoteSSH'):
    # !git clone https://github.com/Quanquan1906/remoteSSH.git
# Out:
# Cloning into 'remoteSSH'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 1), reused 14 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/remoteSSH
# Out:
# /kaggle/working/remoteSSH

# %%
from remote_setup import setup_github_config, connect_vscode, clone_project_from_github
setup_github_config('/kaggle/input/myprojecttree/Admin_rsa')
clone_project_from_github(giturl='git@github.com:enfr-mt-group/mt-enfr-lstm.git',
                          folder='/kaggle/working/enfr-mt-group',
                          branch='base-attention-beemsearch')
# connect_vscode()
# Out:
# setup github_config finished
# Cloning into '/kaggle/working/enfr-mt-group'...
#
# remote: Enumerating objects: 972, done.
# remote: Counting objects: 100% (236/236), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 972 (delta 155), reused 188 (delta 116), pack-reused 736 (from 1)
# Receiving objects: 100% (972/972), 421.88 MiB | 45.49 MiB/s, done.
# Resolving deltas: 100% (463/463), done.

# %%
cd /kaggle/working/enfr-mt-group
# Out:
# /kaggle/working/enfr-mt-group

# %%
# !git checkout base-attention-beemsearch
# !git pull origin base-attention-beemsearch # remember cd your project
# !git add .
# !git config --global user.email "doquan19062004@gmail.com"
# !git config --global user.name "Quann"
# !git commit -m "setup 2017 attention"
# !git push https://doquan19062004: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@github.com/enfr-mt-group/mt-enfr-lstm.git base-attention-beemsearch

# %% [markdown]
# # **Mô hình LSTM ENGLISH TO FRANCE**

# %%
# !python /kaggle/working/enfr-mt-group/enfr-main/src/main/main.py --exp A4
# Out:
# Using preset: A4
# {'embed_dim': 512, 'hidden_dim': 512, 'num_layers': 3, 'dropout': 0.3, 'batch_size': 128, 'lr': 0.001, 'teacher_forcing_ratio': 0.5, 'n_epochs': 20, 'use_attention': True}
# Building DataLoaders...
# Tokenizing EN: 100%|███████████████████| 29000/29000 [00:00<00:00, 29135.07it/s]
# Tokenizing FR: 100%|███████████████████| 29000/29000 [00:01<00:00, 18290.27it/s]
# Tokenizing EN: 100%|█████████████████████| 1014/1014 [00:00<00:00, 35037.48it/s]
# Tokenizing FR: 100%|█████████████████████| 1014/1014 [00:00<00:00, 22657.78it/s]
# Tokenizing EN: 100%|█████████████████████| 1000/1000 [00:00<00:00, 38065.33it/s]
# Tokenizing FR: 100%|█████████████████████| 1000/1000 [00:00<00:00, 26394.04it/s]
# Dataset sizes: Train=29000, Val=1014, Test=1000
# Vocab sizes: EN=9797, FR=10004
# Model initialized
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/20] | Train Loss: 5.0302 | Val Loss: 4.3662
#  Best model saved
# Epoch [2/20] | Train Loss: 4.1169 | Val Loss: 3.7209
#  Best model saved
# Epoch [3/20] | Train Loss: 3.5487 | Val Loss: 3.2432
#  Best model saved
# Epoch [4/20] | Train Loss: 3.0935 | Val Loss: 2.9161
#  Best model saved
# Epoch [5/20] | Train Loss: 2.7564 | Val Loss: 2.6678
#  Best model saved
# Epoch [6/20] | Train Loss: 2.4990 | Val Loss: 2.5528
#  Best model saved
# Epoch [7/20] | Train Loss: 2.2979 | Val Loss: 2.4504
#  Best model saved
# Epoch [8/20] | Train Loss: 2.1169 | Val Loss: 2.3617
#  Best model saved
# Epoch [9/20] | Train Loss: 1.9543 | Val Loss: 2.3033
#  Best model saved
# Epoch [10/20] | Train Loss: 1.8237 | Val Loss: 2.2747
#  Best model saved
# Epoch [11/20] | Train Loss: 1.6924 | Val Loss: 2.2400
#  Best model saved
# Epoch [12/20] | Train Loss: 1.5993 | Val Loss: 2.1869
#  Best model saved
# Epoch [13/20] | Train Loss: 1.5050 | Val Loss: 2.1819
#  Best model saved
# Epoch [14/20] | Train Loss: 1.4255 | Val Loss: 2.1466
#  Best model saved
# Epoch [15/20] | Train Loss: 1.3506 | Val Loss: 2.1497
# Epoch [16/20] | Train Loss: 1.2865 | Val Loss: 2.1290
#  Best model saved
# Epoch [17/20] | Train Loss: 1.2267 | Val Loss: 2.1329
# Epoch [18/20] | Train Loss: 1.1793 | Val Loss: 2.1270
#  Best model saved
# Epoch [19/20] | Train Loss: 1.1250 | Val Loss: 2.1437
# Epoch [20/20] | Train Loss: 1.0805 | Val Loss: 2.1512
# Training hoàn thành. Best Val Loss: 2.1270
# Figure(1000x600)
# Best model loaded
#
#  Translation examples:
# EN: a man wearing a hat is standing in front of a book store while looking at a window .
# FR(pred): un homme portant un chapeau est debout devant un stand de fruits tout en regardant une canette .
#
# EN: a girl in a pink coat is looking for a book while standing in a building .
# FR(pred): une fille en manteau rose regarde un livre tandis qu' elle est debout dans un bâtiment .
#
# EN: a person wearing goggles is sledding down a hill in front of a building .
# FR(pred): une personne portant des lunettes descend une pente devant un bâtiment .
#
# Evaluating on test set...
#
# ==============================
# Average BLEU score: 0.4267
# Perplexity: 7.4431
# ==============================
#
# ----- EXAMPLES -----
# EN: a boy in a red uniform is attempting to avoid getting out at home plate , while the catcher in the blue uniform is attempting to catch him .
# FR(pred): un garçon en tenue rouge tente de tente de karaté , tandis que le receveur le coureur essaie d' attraper le essaie d' attraper le .
# FR(true): un garçon en uniforme rouge essaie d' éviter de sortir du marbre , tandis que le receveur en tenue bleue essaie de l' attraper .
# BLEU: 0.2347
#
# EN: a woman in blue looks in a black leather bag while sitting on a bench during a sunny afternoon while people and <unk> passed behind her .
# FR(pred): une femme en bleu regarde un sac en cuir noir tandis qu' elle est assise sur un banc pendant qu' une rangée d' oiseaux et des des de l' horizon derrière elle .
# FR(true): une femme en bleu regarde dans un sac en cuir noir tandis qu' elle est assise sur un banc lors d' un après-midi ensoleillé , alors que des gens et une limousine passent derrière elle .
# BLEU: 0.4893
#
# EN: a father - figure and two children outside their home doing yard work such as using a hoe on the grass and planting a tree .
# FR(pred): un père et un enfants et deux enfants se tiennent à manger sur un boulevard tandis qu' il a une prix sur l' herbe et un arbre .
# FR(true): une figure <unk> et deux enfants devant leur maison , faisant des activités de jardinage comme utiliser une binette dans l' herbe et planter un arbre .
# BLEU: 0.0778
#
# EN: a man in light colored clothing photographs a group of men wearing dark suits and hats standing around a woman dressed in a <unk> gown .
# FR(pred): un homme avec des vêtements de couleur vive passe devant un groupe de hommes portant des vêtements d' un des chapeaux et des chapeaux debout autour d' une poubelle de couleur vive .
# FR(true): un homme en tenue claire photographie un groupe d' hommes portant des costumes sombres et des chapeaux , debout autour d' une femme vêtue d' une robe <unk> .
# BLEU: 0.1556
#
# EN: a man in a black t - shirt , cap and jeans is playing drums on an upside down yellow pail .
# FR(pred): un homme avec un t - shirt noir , une casquette et un jean joue de la batterie sur une batterie en métal jaune .
# FR(true): un homme en t - shirt noir , casquette et jean joue de la percussion sur un seau jaune retourné .
# BLEU: 0.2991
#
# Full test results saved to test_full_results.txt
#
# Final BLEU: 0.4267
# Final Perplexity: 7.4431
# Số lượng trọng số: 30
#
# BẢNG 1: DANH SÁCH TOÀN BỘ THAM SỐ
# +-------------------------------+----------------+----------------+
# | Layer Name                    | Tensor Shape   |   Số Parameter |
# +===============================+================+================+
# | encoder.embedding.weight      | [9797, 512]    |        5016064 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l2     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l2     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l2       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l2       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.embedding.weight      | [10004, 512]   |        5122048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l2     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l2     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l2       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l2       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.weight | [512, 512]     |         262144 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.bias   | [512]          |            512 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.weight         | [10004, 1024]  |       10244096 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.bias           | [10004]        |          10004 |
# +-------------------------------+----------------+----------------+
#
# BẢNG 2: EMBEDDING
# +--------------------------+--------------+----------+
# | Layer                    | Shape        |   Params |
# +==========================+==============+==========+
# | encoder.embedding.weight | [9797, 512]  |  5016064 |
# +--------------------------+--------------+----------+
# | decoder.embedding.weight | [10004, 512] |  5122048 |
# +--------------------------+--------------+----------+
#
# BẢNG 3: LSTM ENCODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | encoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l2 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l2 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l2   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l2   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 4: LSTM DECODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | decoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l2 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l2 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l2   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l2   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 5: ATTENTION
# +-------------------------------+------------+----------+
# | Layer                         | Shape      |   Params |
# +===============================+============+==========+
# | decoder.attention.attn.weight | [512, 512] |   262144 |
# +-------------------------------+------------+----------+
# | decoder.attention.attn.bias   | [512]      |      512 |
# +-------------------------------+------------+----------+
#
# BẢNG 6: FULLY CONNECTED OUTPUT
# +-----------------------+---------------+----------+
# | Layer                 | Shape         |   Params |
# +=======================+===============+==========+
# | decoder.fc_out.weight | [10004, 1024] | 10244096 |
# +-----------------------+---------------+----------+
# | decoder.fc_out.bias   | [10004]       |    10004 |
# +-----------------------+---------------+----------+
#
# TỔNG SỐ PARAMETER CỦA MÔ HÌNH: 33,262,356
#
#  Kết quả được lưu vào experiment_results.csv
