# %%
import os
if not os.path.exists('/kaggle/working/remoteSSH'):
    # !git clone https://github.com/Quanquan1906/remoteSSH.git
# Out:
# Cloning into 'remoteSSH'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 1), reused 14 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/remoteSSH
# Out:
# /kaggle/working/remoteSSH

# %%
from remote_setup import setup_github_config, connect_vscode, clone_project_from_github
setup_github_config('/kaggle/input/myprojecttree/Admin_rsa')
clone_project_from_github(giturl='git@github.com:enfr-mt-group/mt-enfr-lstm.git',
                          folder='/kaggle/working/enfr-mt-group',
                          branch='base-attention-beemsearch')
# connect_vscode()
# Out:
# setup github_config finished
# Cloning into '/kaggle/working/enfr-mt-group'...
#
# remote: Enumerating objects: 883, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 883 (delta 112), reused 116 (delta 91), pack-reused 736 (from 1)
# Receiving objects: 100% (883/883), 421.87 MiB | 47.53 MiB/s, done.
# Resolving deltas: 100% (420/420), done.

# %%
cd /kaggle/working/enfr-mt-group
# Out:
# /kaggle/working/enfr-mt-group

# %%
# !git checkout base-attention-beemsearch
# !git pull origin base-attention-beemsearch # remember cd your project
# !git add .
# !git config --global user.email "doquan19062004@gmail.com"
# !git config --global user.name "Quann"
# !git commit -m "setup 2017 attention"
# !git push https://doquan19062004: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@github.com/enfr-mt-group/mt-enfr-lstm.git base-attention-beemsearch

# %% [markdown]
# # **Mô hình LSTM ENGLISH TO FRANCE**

# %%
# !python /kaggle/working/enfr-mt-group/enfr-main/src/main/main.py --exp A5
# Out:
# Using preset: A5
# {'embed_dim': 512, 'hidden_dim': 512, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 64, 'lr': 0.001, 'teacher_forcing_ratio': 0.7, 'n_epochs': 20, 'use_attention': True}
# Building DataLoaders...
# Tokenizing EN: 100%|███████████████████| 29000/29000 [00:00<00:00, 31717.55it/s]
# Tokenizing FR: 100%|███████████████████| 29000/29000 [00:01<00:00, 19547.03it/s]
# Tokenizing EN: 100%|█████████████████████| 1014/1014 [00:00<00:00, 35349.67it/s]
# Tokenizing FR: 100%|█████████████████████| 1014/1014 [00:00<00:00, 23962.86it/s]
# Tokenizing EN: 100%|█████████████████████| 1000/1000 [00:00<00:00, 37090.49it/s]
# Tokenizing FR: 100%|█████████████████████| 1000/1000 [00:00<00:00, 27718.66it/s]
# Dataset sizes: Train=29000, Val=1014, Test=1000
# Vocab sizes: EN=9797, FR=10004
# Model initialized
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/20] | Train Loss: 4.2129 | Val Loss: 3.2482
#  Best model saved
# Epoch [2/20] | Train Loss: 2.9909 | Val Loss: 2.5845
#  Best model saved
# Epoch [3/20] | Train Loss: 2.4197 | Val Loss: 2.2093
#  Best model saved
# Epoch [4/20] | Train Loss: 2.0743 | Val Loss: 2.0347
#  Best model saved
# Epoch [5/20] | Train Loss: 1.8342 | Val Loss: 1.9250
#  Best model saved
# Epoch [6/20] | Train Loss: 1.6416 | Val Loss: 1.8315
#  Best model saved
# Epoch [7/20] | Train Loss: 1.4897 | Val Loss: 1.7880
#  Best model saved
# Epoch [8/20] | Train Loss: 1.3696 | Val Loss: 1.7509
#  Best model saved
# Epoch [9/20] | Train Loss: 1.2720 | Val Loss: 1.7600
# Epoch [10/20] | Train Loss: 1.1835 | Val Loss: 1.7436
#  Best model saved
# Epoch [11/20] | Train Loss: 1.1134 | Val Loss: 1.6945
#  Best model saved
# Epoch [12/20] | Train Loss: 1.0511 | Val Loss: 1.6978
# Epoch [13/20] | Train Loss: 0.9971 | Val Loss: 1.7013
# Epoch [14/20] | Train Loss: 0.9538 | Val Loss: 1.6953
# Early stopping at epoch 14
# Training hoàn thành. Best Val Loss: 1.6945
# Figure(1000x600)
# Best model loaded
#
#  Translation examples:
# EN: a man wearing a hat is standing in front of a book store while looking at a window .
# FR(pred): un homme portant un chapeau est debout devant un magasin tout en regardant par une fenêtre .
#
# EN: a girl in a pink coat is looking for a book while standing in a building .
# FR(pred): une fille en manteau rose regarde un livre tout en étant debout dans un bâtiment .
#
# EN: a person wearing goggles is sledding down a hill in front of a building .
# FR(pred): une personne portant des lunettes de plongée descend une pente devant un bâtiment .
#
# Evaluating on test set...
#
# ==============================
# Average BLEU score: 0.3643
# Perplexity: 7.3076
# ==============================
#
# ----- EXAMPLES -----
# EN: a white truck transport trailer with one end <unk> and the word " <unk> <unk> <unk> right " <unk> on it side on a dirt ground .
# FR(pred): un camion blanc de camion blanc avec une planche de lait et du mot <unk> <unk> <unk> <unk> <unk> <unk> sur imprimé sol , tirant par un sol partiellement colle .
# FR(true): une remorque de transport blanche avec une extrémité <unk> et les mots " <unk> <unk> <unk> <unk> " <unk> dessus , sur un sol en terre .
# BLEU: 0.1187
#
# EN: an aerial landscape photo of <unk> grasses and a castle - like structure peaking through and a mountain landscape in the horizon .
# FR(pred): une vue aérienne d' une classe de classe et d' un <unk> <unk> <unk> <unk> et une montagne recouverte d' eau dans un paysage vallonné .
# FR(true): une photo aérienne d' un paysage d' herbe <unk> avec une sorte de château culminant , et un paysage montagneux à l' horizon .
# BLEU: 0.0316
#
# EN: a black and white photo of a dog staring ahead with a background of signs written in asian language characters .
# FR(pred): un photo et une photo d' un chien , regardant l' air avec un tas de journaux en forme de citron .
# FR(true): une photo en noir et blanc d' un chien regardant droit devant avec un arrière-plan de symboles écrits en caractères asiatiques .
# BLEU: 0.0723
#
# EN: a women bending over with a kissing expression at a black <unk> creature while standing on a <unk> floor .
# FR(pred): une femme se penchant en avant avec un ballon de tennis à l' aide d' une robe noire tandis qu' elle est debout sur une piste pavée .
# FR(true): une femme penchée vers une créature <unk> noire en ayant l' air de l' embrasser , debout sur un plancher en bois .
# BLEU: 0.0259
#
# EN: cyclist on a road with snow covering the surrounding flat landscape and a mountain range in the far background .
# FR(pred): un cycliste sur une route avec de neige neige et le numéro imaginables et une montagne en arrière-plan .
# FR(true): des cyclistes sur une route bordée d' un paysage plat enneigé et une chaîne de montagnes en arrière-plan .
# BLEU: 0.1018
#
#
# Final BLEU: 0.3643
# Final Perplexity: 7.3076
# Số lượng trọng số: 22
#
# BẢNG 1: DANH SÁCH TOÀN BỘ THAM SỐ
# +-------------------------------+----------------+----------------+
# | Layer Name                    | Tensor Shape   |   Số Parameter |
# +===============================+================+================+
# | encoder.embedding.weight      | [9797, 512]    |        5016064 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.embedding.weight      | [10004, 512]   |        5122048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l0     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l0       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l1     | [2048, 512]    |        1048576 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l1       | [2048]         |           2048 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.weight | [512, 512]     |         262144 |
# +-------------------------------+----------------+----------------+
# | decoder.attention.attn.bias   | [512]          |            512 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.weight         | [10004, 1024]  |       10244096 |
# +-------------------------------+----------------+----------------+
# | decoder.fc_out.bias           | [10004]        |          10004 |
# +-------------------------------+----------------+----------------+
#
# BẢNG 2: EMBEDDING
# +--------------------------+--------------+----------+
# | Layer                    | Shape        |   Params |
# +==========================+==============+==========+
# | encoder.embedding.weight | [9797, 512]  |  5016064 |
# +--------------------------+--------------+----------+
# | decoder.embedding.weight | [10004, 512] |  5122048 |
# +--------------------------+--------------+----------+
#
# BẢNG 3: LSTM ENCODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | encoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 4: LSTM DECODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | decoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 5: ATTENTION
# +-------------------------------+------------+----------+
# | Layer                         | Shape      |   Params |
# +===============================+============+==========+
# | decoder.attention.attn.weight | [512, 512] |   262144 |
# +-------------------------------+------------+----------+
# | decoder.attention.attn.bias   | [512]      |      512 |
# +-------------------------------+------------+----------+
#
# BẢNG 6: FULLY CONNECTED OUTPUT
# +-----------------------+---------------+----------+
# | Layer                 | Shape         |   Params |
# +=======================+===============+==========+
# | decoder.fc_out.weight | [10004, 1024] | 10244096 |
# +-----------------------+---------------+----------+
# | decoder.fc_out.bias   | [10004]       |    10004 |
# +-----------------------+---------------+----------+
#
# TỔNG SỐ PARAMETER CỦA MÔ HÌNH: 29,059,860
#
#  Kết quả được lưu vào experiment_results.csv
