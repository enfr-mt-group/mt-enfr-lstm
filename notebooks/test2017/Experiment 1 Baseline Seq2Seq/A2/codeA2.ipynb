# %%
import os
if not os.path.exists('/kaggle/working/remoteSSH'):
    # !git clone https://github.com/Quanquan1906/remoteSSH.git
# Out:
# Cloning into 'remoteSSH'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 1), reused 14 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/remoteSSH
# Out:
# /kaggle/working/remoteSSH

# %%
from remote_setup import setup_github_config, connect_vscode, clone_project_from_github
setup_github_config('/kaggle/input/myprojecttree/Admin_rsa')
clone_project_from_github(giturl='git@github.com:enfr-mt-group/mt-enfr-lstm.git',
                          folder='/kaggle/working/enfr-mt-group',
                          branch='base-attention-beemsearch')
connect_vscode()
# Out:
# setup github_config finished
# Cloning into '/kaggle/working/enfr-mt-group'...
#
# remote: Enumerating objects: 846, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 846 (delta 93), reused 85 (delta 78), pack-reused 736 (from 1)
# Receiving objects: 100% (846/846), 421.87 MiB | 47.03 MiB/s, done.
# Resolving deltas: 100% (401/401), done.
# ********** SETUP SSH SERVICE **********
# New password: Retype new password: passwd: password updated successfully
#  * Restarting OpenBSD Secure Shell server sshd
#    ...done.
# ---------- Finished ----------
# /bin/bash: line 1: kill: `': not a pid or valid job spec
# ********** SETUP NGROK **********
# t=2025-12-10T11:03:04+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.\nRun multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.\nRead more about the agent configuration file: https://ngrok.com/docs/agent/config/ \nYou can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:\nhttps://dashboard.ngrok.com/billing/choose-a-plan\r\n\r\nERR_NGROK_108\r\n"
# ERROR:  authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.
# ERROR:  Run multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.
# ERROR:  Read more about the agent configuration file: https://ngrok.com/docs/agent/config/
# ERROR:  You can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:
# ERROR:  https://dashboard.ngrok.com/billing/choose-a-plan
# ERROR:
# ERROR:  ERR_NGROK_108
# ERROR:  https://ngrok.com/docs/errors/err_ngrok_108
# ERROR:
# t=2025-12-10T11:03:04+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.\nRun multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.\nRead more about the agent configuration file: https://ngrok.com/docs/agent/config/ \nYou can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:\nhttps://dashboard.ngrok.com/billing/choose-a-plan\r\n\r\nERR_NGROK_108\r\n"
# t=2025-12-10T11:03:04+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# The ngrok process errored on start: authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.\nRun multiple endpoints at the same time from a single agent by defining them in your agent configuration file and running `ngrok start --all`.\nRead more about the agent configuration file: https://ngrok.com/docs/agent/config/ \nYou can view your current agent sessions in the dashboard: https://dashboard.ngrok.com/agents. Upgrade to a paid plan to remove this limit:\nhttps://dashboard.ngrok.com/billing/choose-a-plan\r\n\r\nERR_NGROK_108\r\n.
# t=2025-12-10T11:03:05+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T11:03:06+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T11:03:08+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T11:03:12+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# t=2025-12-10T11:03:20+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.en.ngrok-agent.com:443\": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host"
# The ngrok process errored on start: failed to dial ngrok server with address "connect.en.ngrok-agent.com:443": dial tcp: lookup connect.en.ngrok-agent.com on 127.0.0.11:53: no such host.
# > Registry success!
# ssh: NgrokTunnel: "tcp://0.tcp.au.ngrok.io:15652" -> "localhost:22"
# vscode: NgrokTunnel: "https://e9cf6f733f49.ngrok-free.app" -> "http://localhost:9000"

# %%
cd /kaggle/working/enfr-mt-group
# Out:
# /kaggle/working/enfr-mt-group

# %% [markdown]
# # **Mô hình LSTM ENGLISH TO FRANCE**

# %%
# !python /kaggle/working/enfr-mt-group/enfr-main/src/main/main.py --exp A2
# Out:
# Using preset: A2
# {'embed_dim': 512, 'hidden_dim': 512, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'lr': 0.001, 'teacher_forcing_ratio': 0.5, 'n_epochs': 20, 'use_attention': False}
# Building DataLoaders...
# Tokenizing EN: 100%|███████████████████| 29000/29000 [00:00<00:00, 31339.93it/s]
# Tokenizing FR: 100%|███████████████████| 29000/29000 [00:01<00:00, 19558.14it/s]
# Tokenizing EN: 100%|█████████████████████| 1014/1014 [00:00<00:00, 38885.15it/s]
# Tokenizing FR: 100%|█████████████████████| 1014/1014 [00:00<00:00, 25282.66it/s]
# Tokenizing EN: 100%|█████████████████████| 1000/1000 [00:00<00:00, 38145.64it/s]
# Tokenizing FR: 100%|█████████████████████| 1000/1000 [00:00<00:00, 28223.94it/s]
# Dataset sizes: Train=29000, Val=1014, Test=1000
# Vocab sizes: EN=9797, FR=10004
# Model initialized
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/20] | Train Loss: 4.4481 | Val Loss: 3.6750
#  Best model saved
# Epoch [2/20] | Train Loss: 3.4719 | Val Loss: 3.1422
#  Best model saved
# Epoch [3/20] | Train Loss: 3.0144 | Val Loss: 2.8581
#  Best model saved
# Epoch [4/20] | Train Loss: 2.6931 | Val Loss: 2.6599
#  Best model saved
# Epoch [5/20] | Train Loss: 2.4418 | Val Loss: 2.5159
#  Best model saved
# Epoch [6/20] | Train Loss: 2.2344 | Val Loss: 2.4674
#  Best model saved
# Epoch [7/20] | Train Loss: 2.0725 | Val Loss: 2.4311
#  Best model saved
# Epoch [8/20] | Train Loss: 1.9226 | Val Loss: 2.3699
#  Best model saved
# Epoch [9/20] | Train Loss: 1.7895 | Val Loss: 2.3457
#  Best model saved
# Epoch [10/20] | Train Loss: 1.6800 | Val Loss: 2.3410
#  Best model saved
# Epoch [11/20] | Train Loss: 1.5797 | Val Loss: 2.3536
# Epoch [12/20] | Train Loss: 1.4920 | Val Loss: 2.3270
#  Best model saved
# Epoch [13/20] | Train Loss: 1.4182 | Val Loss: 2.3432
# Epoch [14/20] | Train Loss: 1.3485 | Val Loss: 2.3904
# Epoch [15/20] | Train Loss: 1.2898 | Val Loss: 2.3453
# Early stopping at epoch 15
# Training hoàn thành. Best Val Loss: 2.3270
# Figure(1000x600)
# Best model loaded
#
#  Translation examples:
# EN: a man wearing a hat is standing in front of a book store while looking at a window .
# FR(pred): un homme portant un chapeau est debout devant un magasin regardant devant une fenêtre , regardant une fenêtre .
#
# EN: a girl in a pink coat is looking for a book while standing in a building .
# FR(pred): une fille en manteau rose se penche à un un bâtiment en étant debout devant un bâtiment .
#
# EN: a person wearing goggles is sledding down a hill in front of a building .
# FR(pred): une personne portant des lunettes de soleil pose sur un devant devant un bâtiment .
#
# Evaluating on test set...
#
# ==============================
# Average BLEU score: 0.2438
# Perplexity: 15.9651
# ==============================
#
# ----- EXAMPLES -----
# EN: an aerial landscape photo of <unk> grasses and a castle - like structure peaking through and a mountain landscape in the horizon .
# FR(pred): une belle journée de vue ou de seaux et et tarte et une une montagne recouverte de boue dans la forêt forêt .
# FR(true): une photo aérienne d' un paysage d' herbe <unk> avec une sorte de château culminant , et un paysage montagneux à l' horizon .
# BLEU: 0.0119
#
# EN: a black and white photo of a dog staring ahead with a background of signs written in asian language characters .
# FR(pred): une photo de noir et blanc chien regardant un un avec des des avec des des animaux de peluche en peluche .
# FR(true): une photo en noir et blanc d' un chien regardant droit devant avec un arrière-plan de symboles écrits en caractères asiatiques .
# BLEU: 0.0738
#
# EN: a slim asian man in a long white apron and blue hat stringing pasta in a restaurant kitchen .
# FR(pred): un homme asiatique asiatique avec une longue longue carreaux bleue et bleue à carreaux dans une restaurant de restaurant .
# FR(true): un homme asiatique mince avec un long tablier blanc et une casquette bleue étirant des pâtes dans une cuisine de restaurant .
# BLEU: 0.0912
#
# EN: a plane with a banner flying above a beach with people on the sand and in the water .
# FR(pred): un voilier avec un une de sur une plage avec des gens et des gens et l' eau en arrière-plan .
# FR(true): un avion avec une banderole survolant une plage avec des gens sur le sable et dans l' eau .
# BLEU: 0.2283
#
# EN: a woman poses on a rocky beach as her friend takes a photo .
# FR(pred): une femme pose sur une plage de tandis tandis que son ami prend une photo .
# FR(true): une femme pose sur une plage rocheuse , tandis que son amie prend une photo .
# BLEU: 0.5373
#
#
# Final BLEU: 0.2438
# Final Perplexity: 15.9651
# Số lượng trọng số: 20
#
# BẢNG 1: DANH SÁCH TOÀN BỘ THAM SỐ
# +---------------------------+----------------+----------------+
# | Layer Name                | Tensor Shape   |   Số Parameter |
# +===========================+================+================+
# | encoder.embedding.weight  | [9797, 512]    |        5016064 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.embedding.weight  | [10004, 512]   |        5122048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.fc_out.weight     | [10004, 512]   |        5122048 |
# +---------------------------+----------------+----------------+
# | decoder.fc_out.bias       | [10004]        |          10004 |
# +---------------------------+----------------+----------------+
#
# BẢNG 2: EMBEDDING
# +--------------------------+--------------+----------+
# | Layer                    | Shape        |   Params |
# +==========================+==============+==========+
# | encoder.embedding.weight | [9797, 512]  |  5016064 |
# +--------------------------+--------------+----------+
# | decoder.embedding.weight | [10004, 512] |  5122048 |
# +--------------------------+--------------+----------+
#
# BẢNG 3: LSTM ENCODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | encoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 4: LSTM DECODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | decoder.lstm.weight_ih_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 5: ATTENTION
# +---------+---------+----------+
# | Layer   | Shape   | Params   |
# +=========+=========+==========+
# +---------+---------+----------+
#
# BẢNG 6: FULLY CONNECTED OUTPUT
# +-----------------------+--------------+----------+
# | Layer                 | Shape        |   Params |
# +=======================+==============+==========+
# | decoder.fc_out.weight | [10004, 512] |  5122048 |
# +-----------------------+--------------+----------+
# | decoder.fc_out.bias   | [10004]      |    10004 |
# +-----------------------+--------------+----------+
#
# TỔNG SỐ PARAMETER CỦA MÔ HÌNH: 23,675,156
#
#  Kết quả được lưu vào experiment_results.csv
