# %%
import os
if not os.path.exists('/kaggle/working/remoteSSH'):
    # !git clone https://github.com/Quanquan1906/remoteSSH.git
# Out:
# Cloning into 'remoteSSH'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 1), reused 14 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/remoteSSH
# Out:
# /kaggle/working/remoteSSH

# %%
from remote_setup import setup_github_config, connect_vscode, clone_project_from_github
setup_github_config('/kaggle/input/myprojecttree/Admin_rsa')
clone_project_from_github(giturl='git@github.com:enfr-mt-group/mt-enfr-lstm.git',
                          folder='/kaggle/working/enfr-mt-group',
                          branch='base-attention-beemsearch')
connect_vscode()
# Out:
# setup github_config finished
# Cloning into '/kaggle/working/enfr-mt-group'...
#
# remote: Enumerating objects: 846, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 846 (delta 93), reused 85 (delta 78), pack-reused 736 (from 1)
# Receiving objects: 100% (846/846), 421.87 MiB | 45.96 MiB/s, done.
# Resolving deltas: 100% (401/401), done.
# ********** SETUP SSH SERVICE **********
# New password: Retype new password: passwd: password updated successfully
#  * Restarting OpenBSD Secure Shell server sshd
#    ...done.
# ---------- Finished ----------
# /bin/bash: line 1: kill: `': not a pid or valid job spec
# ********** SETUP NGROK **********
# > Registry success!
# ssh: NgrokTunnel: "tcp://8.tcp.ngrok.io:17437" -> "localhost:22"
# vscode: NgrokTunnel: "https://39380e5b8405.ngrok-free.app" -> "http://localhost:9000"

# %%
cd /kaggle/working/enfr-mt-group
# Out:
# /kaggle/working/enfr-mt-group

# %% [markdown]
# # **Mô hình LSTM ENGLISH TO FRANCE**

# %%
# !python /kaggle/working/enfr-mt-group/enfr-main/src/main/main.py --exp A1
# Out:
# Using preset: A1
# {'embed_dim': 256, 'hidden_dim': 512, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'lr': 0.001, 'teacher_forcing_ratio': 0.5, 'n_epochs': 20, 'use_attention': False}
# Building DataLoaders...
# Tokenizing EN: 100%|███████████████████| 29000/29000 [00:00<00:00, 30230.22it/s]
# Tokenizing FR: 100%|███████████████████| 29000/29000 [00:01<00:00, 18487.97it/s]
# Tokenizing EN: 100%|█████████████████████| 1014/1014 [00:00<00:00, 37051.45it/s]
# Tokenizing FR: 100%|█████████████████████| 1014/1014 [00:00<00:00, 24108.34it/s]
# Tokenizing EN: 100%|█████████████████████| 1000/1000 [00:00<00:00, 36383.31it/s]
# Tokenizing FR: 100%|█████████████████████| 1000/1000 [00:00<00:00, 27860.61it/s]
# Dataset sizes: Train=29000, Val=1014, Test=1000
# Vocab sizes: EN=9797, FR=10004
# Model initialized
# Start training...
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/20] | Train Loss: 4.5648 | Val Loss: 3.7969
#  Best model saved
# Epoch [2/20] | Train Loss: 3.6293 | Val Loss: 3.2978
#  Best model saved
# Epoch [3/20] | Train Loss: 3.2020 | Val Loss: 2.9961
#  Best model saved
# Epoch [4/20] | Train Loss: 2.9003 | Val Loss: 2.8350
#  Best model saved
# Epoch [5/20] | Train Loss: 2.6519 | Val Loss: 2.6779
#  Best model saved
# Epoch [6/20] | Train Loss: 2.4394 | Val Loss: 2.6050
#  Best model saved
# Epoch [7/20] | Train Loss: 2.2712 | Val Loss: 2.5046
#  Best model saved
# Epoch [8/20] | Train Loss: 2.1196 | Val Loss: 2.4741
#  Best model saved
# Epoch [9/20] | Train Loss: 1.9844 | Val Loss: 2.4499
#  Best model saved
# Epoch [10/20] | Train Loss: 1.8689 | Val Loss: 2.4157
#  Best model saved
# Epoch [11/20] | Train Loss: 1.7615 | Val Loss: 2.4266
# Epoch [12/20] | Train Loss: 1.6708 | Val Loss: 2.4241
# Epoch [13/20] | Train Loss: 1.5844 | Val Loss: 2.3587
#  Best model saved
# Epoch [14/20] | Train Loss: 1.5090 | Val Loss: 2.3940
# Epoch [15/20] | Train Loss: 1.4388 | Val Loss: 2.4099
# Epoch [16/20] | Train Loss: 1.3756 | Val Loss: 2.4448
# Early stopping at epoch 16
# Training hoàn thành. Best Val Loss: 2.3587
# Figure(1000x600)
# Best model loaded
#
#  Translation examples:
# EN: a man wearing a hat is standing in front of a book store while looking at a window .
# FR(pred): un homme portant un chapeau est debout devant un magasin tandis qu' regardant un livre .
#
# EN: a girl in a pink coat is looking for a book while standing in a building .
# FR(pred): une fille en manteau rose regarde un livre tandis qu' un est debout devant un bâtiment .
#
# EN: a person wearing goggles is sledding down a hill in front of a building .
# FR(pred): une personne avec des lunettes fait du vélo sur un bâtiment devant un bâtiment .
#
# Evaluating on test set...
#
# ==============================
# Average BLEU score: 0.2406
# Perplexity: 16.1945
# ==============================
#
# ----- EXAMPLES -----
# EN: an aerial landscape photo of <unk> grasses and a castle - like structure peaking through and a mountain landscape in the horizon .
# FR(pred): un souffleur de chaparral de bronislaw de des et et des et un paysage et un paysage à l' eau avec des nuages .
# FR(true): une photo aérienne d' un paysage d' herbe <unk> avec une sorte de château culminant , et un paysage montagneux à l' horizon .
# BLEU: 0.0629
#
# EN: a black and white photo of a dog staring ahead with a background of signs written in asian language characters .
# FR(pred): un musicien de noir et blanc sortant d' un chien de un , avec un de de de de de de de de .
# FR(true): une photo en noir et blanc d' un chien regardant droit devant avec un arrière-plan de symboles écrits en caractères asiatiques .
# BLEU: 0.0791
#
# EN: a slim asian man in a long white apron and blue hat stringing pasta in a restaurant kitchen .
# FR(pred): un homme asiatique avec un chapeau et une barbe blanche et des tablier bleu dans dans un restaurant bondé .
# FR(true): un homme asiatique mince avec un long tablier blanc et une casquette bleue étirant des pâtes dans une cuisine de restaurant .
# BLEU: 0.0725
#
# EN: a plane with a banner flying above a beach with people on the sand and in the water .
# FR(pred): un taxi avec un coucher de soleil sur une chemin de terre et et coucher de soleil et l' eau .
# FR(true): un avion avec une banderole survolant une plage avec des gens sur le sable et dans l' eau .
# BLEU: 0.0578
#
# EN: a woman poses on a rocky beach as her friend takes a photo .
# FR(pred): une femme pose sur une plage tout en profitant tandis qu' une femme prend une photo .
# FR(true): une femme pose sur une plage rocheuse , tandis que son amie prend une photo .
# BLEU: 0.4385
#
#
# Final BLEU: 0.2406
# Final Perplexity: 16.1945
# Số lượng trọng số: 20
#
# BẢNG 1: DANH SÁCH TOÀN BỘ THAM SỐ
# +---------------------------+----------------+----------------+
# | Layer Name                | Tensor Shape   |   Số Parameter |
# +===========================+================+================+
# | encoder.embedding.weight  | [9797, 256]    |        2508032 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l0 | [2048, 256]    |         524288 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_ih_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.weight_hh_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_ih_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | encoder.lstm.bias_hh_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.embedding.weight  | [10004, 256]   |        2561024 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l0 | [2048, 256]    |         524288 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l0 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l0   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_ih_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.weight_hh_l1 | [2048, 512]    |        1048576 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_ih_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.lstm.bias_hh_l1   | [2048]         |           2048 |
# +---------------------------+----------------+----------------+
# | decoder.fc_out.weight     | [10004, 512]   |        5122048 |
# +---------------------------+----------------+----------------+
# | decoder.fc_out.bias       | [10004]        |          10004 |
# +---------------------------+----------------+----------------+
#
# BẢNG 2: EMBEDDING
# +--------------------------+--------------+----------+
# | Layer                    | Shape        |   Params |
# +==========================+==============+==========+
# | encoder.embedding.weight | [9797, 256]  |  2508032 |
# +--------------------------+--------------+----------+
# | decoder.embedding.weight | [10004, 256] |  2561024 |
# +--------------------------+--------------+----------+
#
# BẢNG 3: LSTM ENCODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | encoder.lstm.weight_ih_l0 | [2048, 256] |   524288 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | encoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 4: LSTM DECODER
# +---------------------------+-------------+----------+
# | Layer                     | Shape       |   Params |
# +===========================+=============+==========+
# | decoder.lstm.weight_ih_l0 | [2048, 256] |   524288 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l0 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l0   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_ih_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.weight_hh_l1 | [2048, 512] |  1048576 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_ih_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
# | decoder.lstm.bias_hh_l1   | [2048]      |     2048 |
# +---------------------------+-------------+----------+
#
# BẢNG 5: ATTENTION
# +---------+---------+----------+
# | Layer   | Shape   | Params   |
# +=========+=========+==========+
# +---------+---------+----------+
#
# BẢNG 6: FULLY CONNECTED OUTPUT
# +-----------------------+--------------+----------+
# | Layer                 | Shape        |   Params |
# +=======================+==============+==========+
# | decoder.fc_out.weight | [10004, 512] |  5122048 |
# +-----------------------+--------------+----------+
# | decoder.fc_out.bias   | [10004]      |    10004 |
# +-----------------------+--------------+----------+
#
# TỔNG SỐ PARAMETER CỦA MÔ HÌNH: 17,557,524
#
#  Kết quả được lưu vào experiment_results.csv
